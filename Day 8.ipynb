# %%
# %sql
-- DO NOT specify LOCATION at all

CREATE TABLE bronze.events (
  event_id STRING,
  user_id STRING,
  event_time TIMESTAMP
)
USING DELTA;

CREATE TABLE silver.events (
  event_id STRING,
  user_id STRING,
  event_time TIMESTAMP
)
USING DELTA;

CREATE TABLE gold.products (
  product_id STRING,
  product_name STRING,
  revenue DOUBLE,
  purchases INT,
  conversion_rate DOUBLE
)
USING DELTA;
